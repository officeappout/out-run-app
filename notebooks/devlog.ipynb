# %% [markdown]
# Map SSR fix: navigator usage guarded in useMapLogic & BottomJourneyContainer.
# Premium FreeRunView: light mode header + tabs + shared formatPace.

# %% [markdown]
# RunDashboard now uses shared formatPace utility.
